# %%
import pandas as pd
import numpy as np
# from sklearn.preprocessing import PolynomialFeatures
from sklearn import decomposition
import os
import scipy.stats as sc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC

# %%
count = 0

for name in os.listdir('/content/drive/My Drive/Slowness PD/Parkinson-s-Disease-Detection-using-Gait-Analysis-master/CSV'):
    if 'Co' in name:
        count += 1


files = []

for name in os.listdir('/content/drive/My Drive/Slowness PD/Parkinson-s-Disease-Detection-using-Gait-Analysis-master/CSV'):
    if 'Co' in name:
        files.append('/content/drive/My Drive/Slowness PD/Parkinson-s-Disease-Detection-using-Gait-Analysis-master/CSV/' + name)

path = '/content/drive/My Drive/Slowness PD/Parkinson-s-Disease-Detection-using-Gait-Analysis-master/Transformed Data'

# df2 = pd.DataFrame(columns = [col + string for col in df.columns for string in ["Min", "Max", "Std", "Med", "Avg", "Skewness", "Kurtosis", "Moment"]])
i = 0
j = 0
df2 = pd.DataFrame()
for fname in files:
    global df, df2


    df = pd.read_csv(fname)
    for col in df.columns:
        for x in ["Min", "Max", "Std", "Med", "Avg", "Skewness", "Kurtosis"]:
            colname = col + x
            if x == 'Min':
                df2.loc[i, colname] = df[col].min(axis=0)

            if x == 'Max':
                df2.loc[i, colname] = df[col].max(axis=0)

            if x == 'Std':
                df2.loc[i, colname] = df[col].std(axis=0)

            if x == 'Med':
                df2.loc[i, colname] = df[col].median(axis=0)

            if x == 'Avg':
                df2.loc[i, colname] = df[col].mean(axis=0)
            if x == 'Skewness':
                df2.loc[i, colname] = df[col].skew(axis=0)

            if x == 'Kurtosis':
                df2.loc[i, colname] = df[col].kurtosis(axis=0)


    i += 1
    j += 1
    print("{} files completed out of {}".format(j, count))
# Out:
# 1 files completed out of 92
# 2 files completed out of 92
# 3 files completed out of 92
# 4 files completed out of 92
# 5 files completed out of 92
# 6 files completed out of 92
# 7 files completed out of 92
# 8 files completed out of 92
# 9 files completed out of 92
# 10 files completed out of 92
# 11 files completed out of 92
# 12 files completed out of 92
# 13 files completed out of 92
# 14 files completed out of 92
# 15 files completed out of 92
# 16 files completed out of 92
# 17 files completed out of 92
# 18 files completed out of 92
# 19 files completed out of 92
# 20 files completed out of 92
# 21 files completed out of 92
# 22 files completed out of 92
# 23 files completed out of 92
# 24 files completed out of 92
# 25 files completed out of 92
# 26 files completed out of 92
# 27 files completed out of 92
# 28 files completed out of 92
# 29 files completed out of 92
# 30 files completed out of 92
# 31 files completed out of 92
# 32 files completed out of 92
# ...

# %%
df2 = df2.dropna(thresh=50)

# %%
df2
# Out:
#     Time(sec)Min  ...  Total_force_rightKurtosis
# 0           0.01  ...                  -1.698395
# 1           0.01  ...                  -1.797104
# 2           0.01  ...                  -1.549758
# 3           0.01  ...                  -1.646734
# 4           0.01  ...                  -1.844673
# ..           ...  ...                        ...
# 87          0.01  ...                  -1.768606
# 88          0.01  ...                  -1.797642
# 89          0.01  ...                  -1.701348
# 90          0.01  ...                  -1.766665
# 91          0.01  ...                  -1.725230
#
# [92 rows x 133 columns]

# %%
count = 0

for name in os.listdir('/content/drive/My Drive/Slowness PD/Parkinson-s-Disease-Detection-using-Gait-Analysis-master/Transformed Data'):
    if 'Pt' in name:
      count += 1
print(count)

files = []

for name in os.listdir('/content/drive/My Drive/Slowness PD/Parkinson-s-Disease-Detection-using-Gait-Analysis-master/CSV'):
    if 'Pt' in name:
        files.append('/content/drive/My Drive/Slowness PD/Parkinson-s-Disease-Detection-using-Gait-Analysis-master/CSV/' + name)

path = '/content/drive/My Drive/Slowness PD/Parkinson-s-Disease-Detection-using-Gait-Analysis-master/Transformed Data'

# df2 = pd.DataFrame(columns = [col + string for col in df.columns for string in ["Min", "Max", "Std", "Med", "Avg", "Skewness", "Kurtosis", "Moment"]])
i = 0
j = 0
df4 = pd.DataFrame()
for fname in files:
    global df3, df4


    df3 = pd.read_csv(fname)
    for col in df.columns:
        for x in ["Min", "Max", "Std", "Med", "Avg", "Skewness", "Kurtosis"]:
            colname = col + x
            if x == 'Min':
                df4.loc[i, colname] = df3[col].min(axis=0)

            if x == 'Max':
                df4.loc[i, colname] = df3[col].max(axis=0)

            if x == 'Std':
                df4.loc[i, colname] = df3[col].std(axis=0)

            if x == 'Med':
                df4.loc[i, colname] = df3[col].median(axis=0)

            if x == 'Avg':
                df4.loc[i, colname] = df3[col].mean(axis=0)
            if x == 'Skewness':
                df4.loc[i, colname] = df3[col].skew(axis=0)

            if x == 'Kurtosis':
                df4.loc[i, colname] = df3[col].kurtosis(axis=0)


    i += 1
    j += 1
    print("{} files completed out of {}".format(j, count))
# Out:
# 1
# 1 files completed out of 1
# 2 files completed out of 1
# 3 files completed out of 1
# 4 files completed out of 1
# 5 files completed out of 1
# 6 files completed out of 1
# 7 files completed out of 1
# 8 files completed out of 1
# 9 files completed out of 1
# 10 files completed out of 1
# 11 files completed out of 1
# 12 files completed out of 1
# 13 files completed out of 1
# 14 files completed out of 1
# 15 files completed out of 1
# 16 files completed out of 1
# 17 files completed out of 1
# 18 files completed out of 1
# 19 files completed out of 1
# 20 files completed out of 1
# 21 files completed out of 1
# 22 files completed out of 1
# 23 files completed out of 1
# 24 files completed out of 1
# 25 files completed out of 1
# 26 files completed out of 1
# 27 files completed out of 1
# 28 files completed out of 1
# 29 files completed out of 1
# 30 files completed out of 1
# 31 files completed out of 1
# 32 files completed out of 1
# 33 files completed out of 1
# ...

# %%
df4 = df4.dropna(thresh=50)

# %%
df4
# Out:
#      Time(sec)Min  ...  Total_force_rightKurtosis
# 0            0.01  ...                  -1.823905
# 1            0.01  ...                  -1.611125
# 2            0.01  ...                  -1.805583
# 3            0.01  ...                  -1.668055
# 4            0.01  ...                  -1.708151
# ..            ...  ...                        ...
# 209          0.01  ...                  -1.717486
# 210          0.01  ...                  -1.725510
# 211          0.01  ...                  -1.763312
# 212          0.01  ...                  -1.749925
# 213          0.01  ...                  -1.793014
#
# [214 rows x 133 columns]

# %%
df_co = df2
df_pt = df4

# %%
# pca1 = decomposition.PCA(n_components=50)
# df_co_pca = pca1.fit_transform(df_co)
# df_pt_pca = pca1.fit_transform(df_pt)

df_co_pca= df_co
df_pt_pca= df_pt

# %%
df_co_len = df_co_pca.shape[0]
df_pt_len = df_pt_pca.shape[0]

# %%
df_co_pca = pd.DataFrame(df_co_pca)
df_pt_pca = pd.DataFrame(df_pt_pca)

# %%
X = pd.concat([df_co_pca, df_pt_pca])

# %%
y1 = pd.Series([0]*df_co_len)
y1.shape
# Out:
# (92,)

# %%
y2 = pd.Series([1]*df_pt_len, index = range(df_co_len-1,(df_co_len + df_pt_len)-1))
y2.shape
# Out:
# (214,)

# %%
y = pd.concat([y1,y2])
y.shape
# Out:
# (306,)

# %%
X_train, X_test, y_train1, y_test1 = train_test_split(X, y)
y_train = pd.DataFrame(y_train1)
y_test = pd.DataFrame(y_test1)
df = pd.DataFrame(X_test)
testFile="/content/drive/My Drive/x_test_gait.csv"
df.to_csv(testFile, encoding='utf-8', index=False)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (229, 133)
# (77, 133)
# (229, 1)
# (77, 1)

# %%
scaler = MinMaxScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Defining accuracy, precision, recall and F1

# %%
def accuracy(prediction,actual):
    correct = 0
    not_correct = 0
    for i in range(len(prediction)):
        if prediction[i] == actual[i]:
            correct+=1
        else:
            not_correct+=1
    return float("{0:.2f}".format((correct*100)/(correct+not_correct)))


def metrics(prediction,actual):
    tp = 0
    tn = 0
    fp = 0
    fn = 0
    for i in range(len(prediction)):
        if prediction[i] == actual[i] and actual[i]==1:
            tp+=1
        if prediction[i] == actual[i] and actual[i]==0:
            tn+=1
        if prediction[i] != actual[i] and actual[i]==0:
            fp+=1
        if prediction[i] != actual[i] and actual[i]==1:
            fn+=1
    metrics = {'Precision':(tp/(tp+fp)),'Sensitivity':(tp/(tp+fn)),'Specificity':(tn/(tn+fp)),'F1':(2*(tp/(tp+fp))*(tp/(tp+fn)))/((tp/(tp+fp))+(tp/(tp+fn)))}
    return (metrics)

# %% [markdown]
# # Importing sklearn libraries for various algorithms

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import VotingClassifier

# %% [markdown]
# # Logistic Regression

# %%
clf1=LogisticRegression()
clf1.fit(X_train, y_train1)
preds=clf1.predict(X_test)
LR = accuracy(y_test1.tolist(), preds.tolist())
print('accuracy:',LR, '%')
print(metrics(y_test1.tolist(), preds.tolist()))
# Out:
# accuracy: 75.32 %
# {'Precision': 0.9387755102040817, 'Sensitivity': 0.7419354838709677, 'Specificity': 0.8, 'F1': 0.828828828828829}

# %% [markdown]
# # Random Forest

# %%
import pickle
clf2=RandomForestClassifier(n_estimators=100)
clf2.fit(X_train, y_train1)

# Save the trained model as a pickle string.
filename="/content/drive/My Drive/gait_model.sav"
pickle.dump(clf2, open(filename, 'wb'))
preds=clf2.predict(X_test)
RF = accuracy(y_test1.tolist(), preds.tolist())
print('accuracy:',RF, '%')
print(metrics(y_test1.tolist(), preds.tolist()))
# Out:
# accuracy: 83.12 %
# {'Precision': 0.9591836734693877, 'Sensitivity': 0.8103448275862069, 'Specificity': 0.8947368421052632, 'F1': 0.8785046728971961}

# %% [markdown]
# # Support Vector Machine

# %%
clf3=SVC()
clf3.fit(X_train, y_train1)
preds=clf3.predict(X_test)
SVM = accuracy(y_test1.tolist(), preds.tolist())
print('accuracy:',SVM, '%')
print(metrics(y_test1.tolist(), preds.tolist()))
# Out:
# accuracy: 76.62 %
# {'Precision': 0.9795918367346939, 'Sensitivity': 0.7384615384615385, 'Specificity': 0.9166666666666666, 'F1': 0.8421052631578948}

# %% [markdown]
# # KNeighbors Classifier

# %%
clf4=KNeighborsClassifier()
clf4.fit(X_train, y_train1)
preds=clf4.predict(X_test)
KN = accuracy(y_test1.tolist(), preds.tolist())
print('accuracy:',KN, '%')
print(metrics(y_test1.tolist(), preds.tolist()))
# Out:
# accuracy: 74.03 %
# {'Precision': 0.8979591836734694, 'Sensitivity': 0.7457627118644068, 'Specificity': 0.7222222222222222, 'F1': 0.8148148148148148}

# %% [markdown]
# # Adaptive Boosting

# %%
# svc=SVC(probability=True, kernel='linear')
clf5=AdaBoostClassifier(n_estimators=100,learning_rate=1)
clf5.fit(X_train, y_train1)
preds=clf5.predict(X_test)
AB = accuracy(y_test1.tolist(), preds.tolist())
print('accuracy:',AB, '%')
print(metrics(y_test1.tolist(), preds.tolist()))
# Out:
# accuracy: 79.22 %
# {'Precision': 0.9387755102040817, 'Sensitivity': 0.7796610169491526, 'Specificity': 0.8333333333333334, 'F1': 0.8518518518518519}

# %% [markdown]
# # Decision Tree

# %%
clf6=DecisionTreeClassifier(criterion="entropy", max_depth=3)
clf6.fit(X_train, y_train1)
preds=clf6.predict(X_test)
DT = accuracy(y_test1.tolist(), preds.tolist())
print('accuracy:',DT, '%')
print(metrics(y_test1.tolist(), preds.tolist()))
# Out:
# accuracy: 70.13 %
# {'Precision': 0.7346938775510204, 'Sensitivity': 0.782608695652174, 'Specificity': 0.5806451612903226, 'F1': 0.7578947368421053}

# %% [markdown]
# # Stochastic Gradient Descent

# %%
clf7 = SGDClassifier(loss="hinge", penalty="l2", max_iter=5)
clf7.fit(X_train, y_train1)
preds=clf7.predict(X_test)
SGD = accuracy(y_test1.tolist(), preds.tolist())
print('accuracy:',SGD, '%')
print(metrics(y_test1.tolist(), preds.tolist()))
# Out:
# accuracy: 77.92 %
# {'Precision': 0.9591836734693877, 'Sensitivity': 0.7580645161290323, 'Specificity': 0.8666666666666667, 'F1': 0.8468468468468467}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_stochastic_gradient.py:557: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning)

# %% [markdown]
# # Neural Network

# %%
clf8 = MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(5, 2), random_state=1)
clf8.fit(X_train, y_train1)
preds=clf8.predict(X_test)
NN = accuracy(y_test1.tolist(), preds.tolist())
print('accuracy:',NN, '%')
print(metrics(y_test1.tolist(), preds.tolist()))
# Out:
# accuracy: 85.71 %
# {'Precision': 0.88, 'Recall': 0.8979591836734694, 'F1': 0.888888888888889}

# %% [markdown]
# # Voting

# %%
eclf1 = VotingClassifier(estimators=[('lr', clf1), ('rf', clf2), ('svm', clf3), ('kn', clf4), ('ab', clf5), ('dt', clf6)], voting='hard')
eclf1.fit(X_train, y_train1)
preds=eclf1.predict(X_test)
v = accuracy(y_test1.tolist(), preds.tolist())
print('accuracy:',v, '%')
print(metrics(y_test1.tolist(), preds.tolist()))
# Out:
# accuracy: 80.52 %
# {'Precision': 0.9183673469387755, 'Sensitivity': 0.8035714285714286, 'Specificity': 0.8095238095238095, 'F1': 0.8571428571428571}

# %% [markdown]
# # Plotting graph

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

COLOR = 'white'
mpl.rcParams['text.color'] = COLOR
mpl.rcParams['axes.labelcolor'] = COLOR
mpl.rcParams['xtick.color'] = COLOR
mpl.rcParams['ytick.color'] = COLOR

fig, ax = plt.subplots(facecolor='#095481')
# x-coordinates of left sides of bars
left = [1, 2, 3, 4, 5, 6, 7]

# heights of bars
height = [LR, RF, SVM, KN, AB, DT, SGD]

# labels for bars
tick_label = ['LR', 'RF', 'SV', 'KN', 'AB', 'DT', 'SGD']

# plotting a bar chart
plt.bar(left, height, tick_label = tick_label,
        width = 0.2, color = ['white'])

# naming the x-axis
plt.xlabel('methods')
# naming the y-axis
plt.ylabel('accuracy')
# plot title

# for i, v in enumerate(height):
#     plt.text(left[i] - 0.30, v + 0.5, str(v))

ax.set_facecolor("#095481")
ax.spines['bottom'].set_color('white')
ax.spines['top'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')


ax.set_clip_on(False)
# function to show the plot
plt.show()

# %%
import matplotlib.pyplot as subaxes
for this_gamma, this_axis in zip([0.01, 1, 5], subaxes):

    for this_C, subplot in zip([0.1, 1, 15, 250], this_axis):

        clf = SVC(kernel = 'rbf', gamma = this_gamma, C = this_C).fit(X_train, y_train)
        print('gamma = {:.2f}, C = {:.2f}, accuracy = {}'.format(this_gamma, this_C, clf.score(X_test, np.ravel(y_test))))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-565e93ddec5d> in <module>()
#       1 import matplotlib.pyplot as subaxes
# ----> 2 for this_gamma, this_axis in zip([0.01, 1, 5], subaxes):
#       3
#       4     for this_C, subplot in zip([0.1, 1, 15, 250], this_axis):
#       5
#
# TypeError: zip argument #2 must support iteration

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
